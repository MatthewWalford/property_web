# %%
import requests
from bs4 import BeautifulSoup
import re

from random_user_agent.user_agent import UserAgent
from random_user_agent.params import SoftwareName, OperatingSystem

import time
from random import random
from datetime import datetime
import os

import pandas as pd
import numpy as np

from pprint import pprint

# %%
#Function to generate a randomised user agent for each connection 
def agent_randomiser():
    software_names = [SoftwareName.CHROME.value]
    operating_systems = [OperatingSystem.WINDOWS.value, OperatingSystem.LINUX.value]   

    user_agent_rotator = UserAgent(software_names=software_names, operating_systems=operating_systems, limit=100)

    # Get list of user agents.
    user_agents = user_agent_rotator.get_user_agents()

    # Get Random User Agent String.
    user_agent = user_agent_rotator.get_random_user_agent()
    
    user_agent2 = {"User-Agent": user_agent}
    
    return user_agent2

# %%
#Specify suburbs; note if multiple suburbs, then need to 
suburbs = ['blackburn']
state = ['vic']
postcode = ['3130']

# create a list of root urls of suburbs to scrape
if len(suburbs) == 1:   
    root_url =  'https://www.domain.com.au/sold-listings/%s-%s-%s/?excludepricewithheld=1&ssubs=0' %(suburbs[0],state[0],postcode[0])
else:
    root_url = []
    for i,suburb in enumerate(suburbs):
        root_url.append('https://www.domain.com.au/sold-listings/%s-%s-%s/?excludepricewithheld=1&ssubs=0' %(suburb,state[i],postcode[i]))

# %%
# headers = {"User-Agent": 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36'}

search={}

res = requests.get(root_url, headers=agent_randomiser())

if res.status_code == 200:
    print("Response from website:",res.status_code)

    soup_the_page = BeautifulSoup(res.content,features='lxml')
    properties_total_return = soup_the_page.find_all('h1',{'data-testid': 'summary'})
    total_properties = properties_total_return[0].text.split()[0]

    #This rounds up the number of URLs to srape from the base url
    total_pages = -(-(int(total_properties))//20)
    print("Pages to Search:",total_pages)

    #This is where the extracted information is appended to the search dictionary for use in later processing. 
    search.update({suburbs[0]: {'Suburb': suburbs[0],
                                'Total properties':total_properties,
                                'Pages to Search':total_pages,
                                'Root Url':root_url,
                                'Website Response': res.status_code}})

    print("Appended to the Search dictionary")
else:
    print("Response from website:",res.status_code)
    
    search.update({suburbs[0]: {'Suburb': 'UNABLE TO EXTRACT',
                                'Total properties':'UNABLE TO EXTRACT',
                                'Pages to Search':'UNABLE TO EXTRACT',
                                'Root Url':root_url,
                                'Website Response': res.status_code}})

print('\n',search)
# Out:
# Response from website: 200
# Pages to Search: 80
# Appended to the Search dictionary
#
#  {'blackburn': {'Suburb': 'blackburn', 'Total properties': '1587', 'Pages to Search': 80, 'Root Url': 'https://www.domain.com.au/sold-listings/blackburn-vic-3130/?excludepricewithheld=1&ssubs=0', 'Website Response': 200}}

# %%
#6. This creates the list of specific job page urls to iterate through
#This is **NOT** the individual job ads but rather the top-level search pages for each search criteria that will need to be
#searched through to extract specific job URLs that will contain the required information.
#Output is appended to the search dictionary under the key URL Search Page List for each search term

for k,value in search.items():
#     print(k,value)
    web_url_iterations = []
    #This get the root URL and drops the final character which is a 0 for the page
    url = value.get('Root Url') + str('&page=') #[:-1]
    
    if value.get('Pages to Search') > 50:
        web_url_iterations.append(value.get('Root Url'))
        iterations = 2                             #<--THIS HAS BEEN SET TO 2 FOR TESTING. UPDATE TO 50 ONCE CONFIRMED WORKING
        for i in range(1,iterations):
            web_url_iterations.append(str(url + str((i+1))))
            value.update({'URL Search Page List': web_url_iterations})
            
    elif value.get('Pages to Search') == 1:
        web_url_iterations.append(value.get('Root Url'))
    
    elif value.get('Pages to Search') == 'UNABLE TO EXTRACT':
        print('Was unable to extract a root url. Check website response')
        value.update({'URL Search Page List': 'Was unable to extract a root url. Check website response'})
    
    else:
        web_url_iterations.append(value.get('Root Url'))
        iterations = value.get('Pages to Search')
        for i in range(1,iterations):
            web_url_iterations.append(str(url + str((i+1))))
            value.update({'URL Search Page List': web_url_iterations})

# %%
for k,value in search.items():
    search_url = value.get('URL Search Page List')
    unique_property_url = []
    
    for url in search_url:
        print('------------')
        print(url)
        
        time.sleep(random()*4)
        
        content = requests.get(url, headers=agent_randomiser())
        print("Response from website:",content.status_code)
        
        if content.status_code == 200:
            property_pane = BeautifulSoup(content.content,features='lxml')
            unique_links = property_pane.find_all('link',{'itemprop':'url'})
            for a in unique_links:
                unique_property_url.append(str(a).split('"')[1])
            value.update({'Specific property URLs': unique_property_url})
        else:
            print('An issue with the website occured. Please check website status code')
# Out:
# ------------
# https://www.domain.com.au/sold-listings/blackburn-vic-3130/?excludepricewithheld=1&ssubs=0
# Response from website: 200
# ------------
# https://www.domain.com.au/sold-listings/blackburn-vic-3130/?excludepricewithheld=1&ssubs=0&page=2
# Response from website: 200

# %%
unique_property_brochure = []

for k,value in search.items():
    list_values = value.get('Specific property URLs')
    
    for pid in list_values:
        unique_id = pid.split("-")[-1]
        brochure_url =  'https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=%s&mode=sold' %(unique_id)
        unique_property_brochure.append(brochure_url)
#         print(brochure_url)
        
    value.update({'Brochure Links':unique_property_brochure})

# %%
all_properties=[]

counter = 0

for k,value in search.items():
    print('\nGetting information for',str(value.get('Suburb')).upper())
    print('---------------')
    property_urls_suburb = value.get('Brochure Links')
    
    property_original_urls = value.get('Specific property URLs')
#     print('List of property links for', str(value.get('Suburb')).upper())
#     pprint(property_urls_suburb)
    
    for i in property_urls_suburb:
        
#         os.system('cls')
#         print(i)
        time.sleep(random()*5)
        property_info = {}
        
        print('Connecting to ', i)
        web_response3 = requests.get(i, headers=agent_randomiser())
        print("Response from website:",web_response3.status_code)
        if web_response3.status_code == 200:
            property_extract = BeautifulSoup(web_response3.content,features='lxml')                    
            property_summary_pane = property_extract.find_all('div',{'style':'margin: 0 10px 10px'})
            
            #Search date for appending
            search_date_time = datetime.now()
            property_info['search_date'] = search_date_time.strftime("%d %b %y %T")
            
            #Original url
            property_info['url'] = i
            
            #Property address
            address = property_extract.find('h2').text.split("\r")[0]
            property_info['address'] = address
            
            #Property suburb
            property_info['suburb'] = k
            
            #Property sale value
            try:
                sold_price = property_extract.find('h1').text.split("$")[1].replace(",","")
                property_info['sold_price'] = sold_price
            except:
                property_info['sold_price'] = 'unknown'
            
            #Extract beds, baths, carspaces, and Land Area
            appending_info = []            
            
            strong_list = []

            for strong_tag in property_summary_pane[0].find_all('strong'):
            #     print(strong_tag.next_sibling.split())
                strong_list.append(strong_tag.next_sibling.split())

            for x in strong_list:
                if len(x) == 1:
                    pass
                elif len(x)>1:
                    property_info['bedrooms'] = 'unknown'
                    property_info['bathrooms'] = 'unknown'
                    property_info['carspaces'] = 'unknown'
                    for i,o in enumerate(x):
                        if o == 'bedrooms' or o == 'bedroom':
                            property_info['bedrooms'] = x[i-1]
                        if o == 'bathrooms' or o == 'bathroom':
                            property_info['bathrooms'] = x[i-1]
                        if o == 'carspace' or o == 'carspaces':
                            property_info['carspaces'] = x[i-1]  
    
            
            for st in property_extract.find_all('strong'):
                property_info['land area'] = 'unknown'
                if st.text == "Land area:":
                    property_info['land area'] = float(st.next_sibling.split()[0])
#                     print(float(st.next_sibling.split()[0]))
            
            all_properties.append(property_info)
            print('****')
        else:
            print("!!!!!!!!!!!!!!!!!!!!!")
            print("Something went wrong!")
            print("!!!!!!!!!!!!!!!!!!!!!")
# Out:
# Getting information for BLACKBURN
# ---------------
# Connecting to  https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016114099&mode=sold
# Response from website: 200
# ****
# Connecting to  https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016129899&mode=sold
# Response from website: 200
# ****
# Connecting to  https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016127111&mode=sold
# Response from website: 200
# ****
# Connecting to  https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016118973&mode=sold
# Response from website: 200
# ****
# Connecting to  https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016115727&mode=sold
# Response from website: 200
# ****
# Connecting to  https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016097661&mode=sold
# Response from website: 200
# ****
# Connecting to  https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016093219&mode=sold
# Response from website: 200
# ****
# Connecting to  https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016082845&mode=sold
# Response from website: 200
# ****
# Connecting to  https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016078202&mode=sold
# Response from website: 200
# ****
# Connecting to  https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016167905&mode=sold
# Response from website: 200
# ****
# Connecting to  https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016085500&mode=sold
# Response from website: 200
# ****
# Connecting to  https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016083672&mode=sold
# Response from website: 200
# ****
# Connecting to  https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016062122&mode=sold
# Response from website: 200
# ****
# Connecting to  https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016073284&mode=sold
# Response from website: 200
# ****
# Connecting to  https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016001151&mode=sold
# Response from website: 200
# ****
# Connecting to  https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016066271&mode=sold
# Response from website: 200
# ****
# Connecting to  https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016052515&mode=sold
# Response from website: 200
# ****
# Connecting to  https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016073411&mode=sold
# Response from website: 200
# ****
# Connecting to  https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016033033&mode=sold
# Response from website: 200
# ****
# Connecting to  https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016043634&mode=sold
# Response from website: 200
# ****
# Connecting to  https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016039898&mode=sold
# Response from website: 200
# ****
# Connecting to  https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016032940&mode=sold
# Response from website: 200
# ****
# Connecting to  https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016022267&mode=sold
# Response from website: 200
# ****
# Connecting to  https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016022096&mode=sold
# Response from website: 200
# ****
# Connecting to  https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016029432&mode=sold
# Response from website: 200
# ****
# Connecting to  https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016017320&mode=sold
# Response from website: 200
# ****
# Connecting to  https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016027248&mode=sold
# Response from website: 200
# ****
# Connecting to  https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016020124&mode=sold
# Response from website: 200
# ****
# Connecting to  https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016093972&mode=sold
# Response from website: 200
# ****
# Connecting to  https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016011952&mode=sold
# Response from website: 200
# ****
# Connecting to  https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016012403&mode=sold
# Response from website: 200
# ****
# Connecting to  https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016003086&mode=sold
# Response from website: 200
# ****
# Connecting to  https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016001545&mode=sold
# Response from website: 200
# ****
# Connecting to  https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016004954&mode=sold
# Response from website: 200
# ****
# Connecting to  https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016006832&mode=sold
# Response from website: 200
# ****
# Connecting to  https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2015998717&mode=sold
# Response from website: 200
# ****
# Connecting to  https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2015842966&mode=sold
# Response from website: 200
# ****
# Connecting to  https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016034575&mode=sold
# Response from website: 200
# ****
# Connecting to  https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2015973611&mode=sold
# Response from website: 200
# ****
# Connecting to  https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2015973108&mode=sold
# Response from website: 200
# ****

# %%
all_properties[0].value('url')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-109-a3570d7e8082> in <module>
# ----> 1 all_properties[0].value('url')
#
# AttributeError: 'dict' object has no attribute 'value'

# %%
for pid,property_id in enumerate(all_properties):
    print(property_id)
    
    
#     time.sleep(random()*5)
#     property_info_2 = {}
    
#     web_response4 = requests.get(search[suburbs[0]]['Specific property URLs'][pid], headers=agent_randomiser())
#     print("Contacting", property_id)
#     print("Response from website:",web_response4.status_code)
    
#     if web_response4.status_code == 200:
#         property_extract_2 = BeautifulSoup(web_response4.content,features='lxml')                    
#         property_summary_pane_2 = property_extract_2.find_all('span',{'class':'listing-details__listing-tag is-sold listing-details__summary-tag'})
        
#         day_sold = property_summary_pane_2[0].text.split()[-3:][0]
#         month_sold = property_summary_pane_2[0].text.split()[-3:][1]
#         year_sold = property_summary_pane_2[0].text.split()[-3:][2]
        
#         property_id['day sold'] = day_sold
#         property_id['month sold'] = month_sold
#         property_id['year sold'] = year_sold
    
#     else:
#         property_id['day sold'] = 'unknown'
#         property_id['month sold'] = 'unknown'
#         property_id['year sold'] = 'unknown'
        
#     print('****')
    
#     original_property_link = se
#     print(pid)
# Out:
# {'search_date': '18 Apr 20 16:26:54', 'url': 'https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016114099&mode=sold', 'address': '22 Francis Street', 'suburb': 'blackburn', 'sold_price': '1199000', 'bedrooms': '4', 'bathrooms': '1', 'carspaces': '2', 'land area': 638.0, 'day sold': '9th', 'month sold': 'April', 'year sold': '2020'}
# {'search_date': '18 Apr 20 16:26:57', 'url': 'https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016129899&mode=sold', 'address': '21 Patricia Road', 'suburb': 'blackburn', 'sold_price': '1255000', 'bedrooms': '2', 'bathrooms': '1', 'carspaces': '2', 'land area': 651.0, 'day sold': '4th', 'month sold': 'April', 'year sold': '2020'}
# {'search_date': '18 Apr 20 16:27:01', 'url': 'https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016127111&mode=sold', 'address': '4/21 Laburnum Street', 'suburb': 'blackburn', 'sold_price': '1190000', 'bedrooms': '3', 'bathrooms': '2', 'carspaces': '2', 'land area': 274.0, 'day sold': '1st', 'month sold': 'April', 'year sold': '2020'}
# {'search_date': '18 Apr 20 16:27:02', 'url': 'https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016118973&mode=sold', 'address': '1 Harold Street', 'suburb': 'blackburn', 'sold_price': '1180000', 'bedrooms': '5', 'bathrooms': '2', 'carspaces': '2', 'land area': 591.0, 'day sold': '31st', 'month sold': 'March', 'year sold': '2020'}
# {'search_date': '18 Apr 20 16:27:07', 'url': 'https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016115727&mode=sold', 'address': '15 Pakenham Street', 'suburb': 'blackburn', 'sold_price': '1400000', 'bedrooms': '3', 'bathrooms': '1', 'carspaces': '2', 'land area': 692.0, 'day sold': '25th', 'month sold': 'March', 'year sold': '2020'}
# {'search_date': '18 Apr 20 16:27:09', 'url': 'https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016097661&mode=sold', 'address': '87 Canterbury Road', 'suburb': 'blackburn', 'sold_price': '1075000', 'bedrooms': '4', 'bathrooms': '2', 'carspaces': '2', 'land area': 611.0, 'day sold': '21st', 'month sold': 'March', 'year sold': '2020'}
# {'search_date': '18 Apr 20 16:27:12', 'url': 'https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016093219&mode=sold', 'address': '1/24-26 Service Road', 'suburb': 'blackburn', 'sold_price': '1108000', 'bedrooms': '3', 'bathrooms': '2', 'carspaces': '2', 'land area': 305.0, 'day sold': '14th', 'month sold': 'March', 'year sold': '2020'}
# {'search_date': '18 Apr 20 16:27:13', 'url': 'https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016082845&mode=sold', 'address': '39 Pope Road', 'suburb': 'blackburn', 'sold_price': '1338000', 'bedrooms': '3', 'bathrooms': '2', 'carspaces': '1', 'land area': 600.0, 'day sold': '14th', 'month sold': 'March', 'year sold': '2020'}
# {'search_date': '18 Apr 20 16:27:15', 'url': 'https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016078202&mode=sold', 'address': '28 Tyrrell Avenue', 'suburb': 'blackburn', 'sold_price': '1690000', 'bedrooms': '3', 'bathrooms': '2', 'carspaces': '1', 'land area': 1190.0}
# {'search_date': '18 Apr 20 16:27:20', 'url': 'https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016167905&mode=sold', 'address': '314/21 Queen Street', 'suburb': 'blackburn', 'sold_price': '530000', 'bedrooms': '2', 'bathrooms': '2', 'carspaces': '2', 'land area': 'unknown'}
# {'search_date': '18 Apr 20 16:27:22', 'url': 'https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016085500&mode=sold', 'address': '314/21 Queen Street', 'suburb': 'blackburn', 'sold_price': '530000', 'bedrooms': '2', 'bathrooms': '2', 'carspaces': '2', 'land area': 'unknown'}
# {'search_date': '18 Apr 20 16:27:27', 'url': 'https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016083672&mode=sold', 'address': '5/28 Lake Road', 'suburb': 'blackburn', 'sold_price': '633000', 'bedrooms': '2', 'bathrooms': '1', 'carspaces': '1', 'land area': 'unknown'}
# {'search_date': '18 Apr 20 16:27:29', 'url': 'https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016062122&mode=sold', 'address': '18 Pakenham Street', 'suburb': 'blackburn', 'sold_price': '1630000', 'bedrooms': '3', 'bathrooms': '2', 'carspaces': '2', 'land area': 283.0}
# {'search_date': '18 Apr 20 16:27:30', 'url': 'https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016073284&mode=sold', 'address': '48 Elmhurst Road', 'suburb': 'blackburn', 'sold_price': '1630000', 'bedrooms': '3', 'bathrooms': '2', 'carspaces': '2', 'land area': 1072.0}
# {'search_date': '18 Apr 20 16:27:31', 'url': 'https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016001151&mode=sold', 'address': '410/394-398 Middleborough Road', 'suburb': 'blackburn', 'sold_price': '505000', 'bedrooms': '2', 'bathrooms': '2', 'carspaces': '2', 'land area': 'unknown'}
# {'search_date': '18 Apr 20 16:27:34', 'url': 'https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016066271&mode=sold', 'address': '3/41 Whitehorse Road', 'suburb': 'blackburn', 'sold_price': '850500', 'bedrooms': '2', 'bathrooms': '1', 'carspaces': '2', 'land area': 217.0}
# {'search_date': '18 Apr 20 16:27:38', 'url': 'https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016052515&mode=sold', 'address': '46 Alandale Road', 'suburb': 'blackburn', 'sold_price': '1391000', 'bedrooms': '3', 'bathrooms': '1', 'carspaces': '1', 'land area': 627.0}
# {'search_date': '18 Apr 20 16:27:41', 'url': 'https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016073411&mode=sold', 'address': 'G02/17-21 Queen Street', 'suburb': 'blackburn', 'sold_price': '551000', 'bedrooms': '2', 'bathrooms': '2', 'carspaces': '1', 'land area': 'unknown'}
# {'search_date': '18 Apr 20 16:27:42', 'url': 'https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016033033&mode=sold', 'address': '2 Pope Road', 'suburb': 'blackburn', 'sold_price': '1335000', 'bedrooms': '3', 'bathrooms': '1', 'carspaces': '1', 'land area': 623.0}
# {'search_date': '18 Apr 20 16:27:43', 'url': 'https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016043634&mode=sold', 'address': '23 Malcolm Street', 'suburb': 'blackburn', 'sold_price': '1408000', 'bedrooms': '3', 'bathrooms': '1', 'carspaces': '1', 'land area': 'unknown'}
# {'search_date': '18 Apr 20 16:27:45', 'url': 'https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016039898&mode=sold', 'address': '2/9 Station Street', 'suburb': 'blackburn', 'sold_price': '690000', 'bedrooms': '2', 'bathrooms': '1', 'carspaces': '2', 'land area': 'unknown'}
# {'search_date': '18 Apr 20 16:27:46', 'url': 'https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016032940&mode=sold', 'address': '1A Vine Street', 'suburb': 'blackburn', 'sold_price': '1665000', 'bedrooms': '3', 'bathrooms': '2', 'carspaces': '2', 'land area': 764.0}
# {'search_date': '18 Apr 20 16:27:50', 'url': 'https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016022267&mode=sold', 'address': '3/109 Blackburn Road', 'suburb': 'blackburn', 'sold_price': '620000', 'bedrooms': '2', 'bathrooms': '1', 'carspaces': '1', 'land area': 'unknown'}
# {'search_date': '18 Apr 20 16:27:51', 'url': 'https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016022096&mode=sold', 'address': '9 Linum Street', 'suburb': 'blackburn', 'sold_price': '2455000', 'bedrooms': '4', 'bathrooms': '2', 'carspaces': '2', 'land area': 1051.0}
# {'search_date': '18 Apr 20 16:27:56', 'url': 'https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016029432&mode=sold', 'address': '5 Dickens Street', 'suburb': 'blackburn', 'sold_price': '1370000', 'bedrooms': '4', 'bathrooms': '2', 'carspaces': '1', 'land area': 626.0}
# {'search_date': '18 Apr 20 16:28:00', 'url': 'https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016017320&mode=sold', 'address': '24 Patricia Road', 'suburb': 'blackburn', 'sold_price': '1411000', 'bedrooms': '4', 'bathrooms': '2', 'carspaces': '2', 'land area': 664.0}
# {'search_date': '18 Apr 20 16:28:05', 'url': 'https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016027248&mode=sold', 'address': '22 Malcolm Street', 'suburb': 'blackburn', 'sold_price': '2000000', 'bedrooms': '5', 'bathrooms': '2', 'carspaces': '2', 'land area': 717.0}
# {'search_date': '18 Apr 20 16:28:07', 'url': 'https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016020124&mode=sold', 'address': '9 Beverley Crescent', 'suburb': 'blackburn', 'sold_price': '1235000', 'bedrooms': '3', 'bathrooms': '1', 'carspaces': '2', 'land area': 716.0}
# {'search_date': '18 Apr 20 16:28:10', 'url': 'https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016093972&mode=sold', 'address': '1/40 Kerr Street', 'suburb': 'blackburn', 'sold_price': '880000', 'bedrooms': '3', 'bathrooms': '2', 'carspaces': '2', 'land area': 260.0}
# {'search_date': '18 Apr 20 16:28:14', 'url': 'https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016011952&mode=sold', 'address': '5 Langtree Court', 'suburb': 'blackburn', 'sold_price': '1450000', 'bedrooms': '4', 'bathrooms': '2', 'carspaces': '1', 'land area': 686.0}
# {'search_date': '18 Apr 20 16:28:19', 'url': 'https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016012403&mode=sold', 'address': '41 Naughton Grove', 'suburb': 'blackburn', 'sold_price': '1430000', 'bedrooms': '4', 'bathrooms': '1', 'carspaces': '2', 'land area': 637.0}
# {'search_date': '18 Apr 20 16:28:23', 'url': 'https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016003086&mode=sold', 'address': '156 Springfield Road', 'suburb': 'blackburn', 'sold_price': '966000', 'bedrooms': '4', 'bathrooms': '2', 'carspaces': '2', 'land area': 438.0}
# {'search_date': '18 Apr 20 16:28:26', 'url': 'https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016001545&mode=sold', 'address': '217/17-21 Queen Street', 'suburb': 'blackburn', 'sold_price': '505000', 'bedrooms': '2', 'bathrooms': '2', 'carspaces': '1', 'land area': 'unknown'}
# {'search_date': '18 Apr 20 16:28:31', 'url': 'https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016004954&mode=sold', 'address': '1/5 Glen Ebor Avenue', 'suburb': 'blackburn', 'sold_price': '980000', 'bedrooms': '3', 'bathrooms': '2', 'carspaces': '2', 'land area': 297.0}
# {'search_date': '18 Apr 20 16:28:35', 'url': 'https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016006832&mode=sold', 'address': '40 Malcolm Street', 'suburb': 'blackburn', 'sold_price': '1439000', 'bedrooms': '3', 'bathrooms': '1', 'carspaces': '1', 'land area': 725.0}
# {'search_date': '18 Apr 20 16:28:37', 'url': 'https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2015998717&mode=sold', 'address': '2/15 Whitehorse Road', 'suburb': 'blackburn', 'sold_price': '1145000', 'bedrooms': '4', 'bathrooms': '2', 'carspaces': '2', 'land area': 'unknown'}
# {'search_date': '18 Apr 20 16:28:39', 'url': 'https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2015842966&mode=sold', 'address': '2E Almer Avenue', 'suburb': 'blackburn', 'sold_price': '1122500', 'bedrooms': '4', 'bathrooms': '3', 'carspaces': '2', 'land area': 'unknown'}
# {'search_date': '18 Apr 20 16:28:39', 'url': 'https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016034575&mode=sold', 'address': '107/300 Middleborough Road', 'suburb': 'blackburn', 'sold_price': '375000', 'bedrooms': '1', 'bathrooms': '1', 'carspaces': '1', 'land area': 'unknown'}
# {'search_date': '18 Apr 20 16:28:41', 'url': 'https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2015973611&mode=sold', 'address': '102/18 Whitehorse Road', 'suburb': 'blackburn', 'sold_price': '463000', 'bedrooms': '2', 'bathrooms': '2', 'carspaces': '1', 'land area': 'unknown'}
# {'search_date': '18 Apr 20 16:28:45', 'url': 'https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2015973108&mode=sold', 'address': '33 Canterbury Road', 'suburb': 'blackburn', 'sold_price': 'unknown', 'bedrooms': '3', 'bathrooms': '2', 'carspaces': '2', 'land area': 347.0}

# %%
property_id
# Out:
# {'search_date': '18 Apr 20 16:27:15',
#  'url': 'https://www.domain.com.au/Public/PropertyBrochure.aspx?adid=2016078202&mode=sold',
#  'address': '28 Tyrrell Avenue',
#  'suburb': 'blackburn',
#  'sold_price': '1690000',
#  'bedrooms': '3',
#  'bathrooms': '2',
#  'carspaces': '1',
#  'land area': 1190.0}

# %%
property_summary_pane_2[0].text.split()[-3:][0]
# Out:
# '1st'

# %%
        for index,property_id in enumerate(property_original_urls):
            time.sleep(random()*5)
            property_info_original = {}
        
            print('Connecting to ', property_id)
        web_response3 = requests.get(i, headers=agent_randomiser())
        print("Response from website:",web_response3.status_code)
        if web_response3.status_code == 200:
            property_extract = BeautifulSoup(web_response3.content,features='lxml')                    
            property_summary_pane = property_extract.find_all('div',{'style':'margin: 0 10px 10px'})            
        
#         os.system('cls')
#         print(i)
        time.sleep(random()*5)
        property_info = {}

# %%
dt_list = []

description_test = property_extract.find_all('h3',{'class':'agentheading'})
print(description_test[2].next_sibling)
for d in description_test:
    print(d.next_sibling)
# Out:
# 					Brand new on own title
#
#
#
#
#
#
# 					Brand new on own title

# %%
df = pd.DataFrame(all_properties)
df.to_csv('df.csv')
df
# Out:
#            search_date                                                url  \
# 0   18 Apr 20 16:26:54  https://www.domain.com.au/Public/PropertyBroch...
# 1   18 Apr 20 16:26:57  https://www.domain.com.au/Public/PropertyBroch...
# 2   18 Apr 20 16:27:01  https://www.domain.com.au/Public/PropertyBroch...
# 3   18 Apr 20 16:27:02  https://www.domain.com.au/Public/PropertyBroch...
# 4   18 Apr 20 16:27:07  https://www.domain.com.au/Public/PropertyBroch...
# 5   18 Apr 20 16:27:09  https://www.domain.com.au/Public/PropertyBroch...
# 6   18 Apr 20 16:27:12  https://www.domain.com.au/Public/PropertyBroch...
# 7   18 Apr 20 16:27:13  https://www.domain.com.au/Public/PropertyBroch...
# 8   18 Apr 20 16:27:15  https://www.domain.com.au/Public/PropertyBroch...
# 9   18 Apr 20 16:27:20  https://www.domain.com.au/Public/PropertyBroch...
# 10  18 Apr 20 16:27:22  https://www.domain.com.au/Public/PropertyBroch...
# 11  18 Apr 20 16:27:27  https://www.domain.com.au/Public/PropertyBroch...
# 12  18 Apr 20 16:27:29  https://www.domain.com.au/Public/PropertyBroch...
# 13  18 Apr 20 16:27:30  https://www.domain.com.au/Public/PropertyBroch...
# 14  18 Apr 20 16:27:31  https://www.domain.com.au/Public/PropertyBroch...
# 15  18 Apr 20 16:27:34  https://www.domain.com.au/Public/PropertyBroch...
# 16  18 Apr 20 16:27:38  https://www.domain.com.au/Public/PropertyBroch...
# 17  18 Apr 20 16:27:41  https://www.domain.com.au/Public/PropertyBroch...
# 18  18 Apr 20 16:27:42  https://www.domain.com.au/Public/PropertyBroch...
# 19  18 Apr 20 16:27:43  https://www.domain.com.au/Public/PropertyBroch...
# 20  18 Apr 20 16:27:45  https://www.domain.com.au/Public/PropertyBroch...
# 21  18 Apr 20 16:27:46  https://www.domain.com.au/Public/PropertyBroch...
# 22  18 Apr 20 16:27:50  https://www.domain.com.au/Public/PropertyBroch...
# 23  18 Apr 20 16:27:51  https://www.domain.com.au/Public/PropertyBroch...
# 24  18 Apr 20 16:27:56  https://www.domain.com.au/Public/PropertyBroch...
# 25  18 Apr 20 16:28:00  https://www.domain.com.au/Public/PropertyBroch...
# 26  18 Apr 20 16:28:05  https://www.domain.com.au/Public/PropertyBroch...
# 27  18 Apr 20 16:28:07  https://www.domain.com.au/Public/PropertyBroch...
# 28  18 Apr 20 16:28:10  https://www.domain.com.au/Public/PropertyBroch...
# 29  18 Apr 20 16:28:14  https://www.domain.com.au/Public/PropertyBroch...
# 30  18 Apr 20 16:28:19  https://www.domain.com.au/Public/PropertyBroch...
# 31  18 Apr 20 16:28:23  https://www.domain.com.au/Public/PropertyBroch...
# 32  18 Apr 20 16:28:26  https://www.domain.com.au/Public/PropertyBroch...
# 33  18 Apr 20 16:28:31  https://www.domain.com.au/Public/PropertyBroch...
# 34  18 Apr 20 16:28:35  https://www.domain.com.au/Public/PropertyBroch...
# 35  18 Apr 20 16:28:37  https://www.domain.com.au/Public/PropertyBroch...
# 36  18 Apr 20 16:28:39  https://www.domain.com.au/Public/PropertyBroch...
# 37  18 Apr 20 16:28:39  https://www.domain.com.au/Public/PropertyBroch...
# 38  18 Apr 20 16:28:41  https://www.domain.com.au/Public/PropertyBroch...
# 39  18 Apr 20 16:28:45  https://www.domain.com.au/Public/PropertyBroch...
#
#                            address     suburb sold_price bedrooms bathrooms  \
# 0                22 Francis Street  blackburn    1199000        4         1
# 1                 21 Patricia Road  blackburn    1255000        2         1
# 2             4/21 Laburnum Street  blackburn    1190000        3         2
# 3                  1 Harold Street  blackburn    1180000        5         2
# 4               15 Pakenham Street  blackburn    1400000        3         1
# 5               87 Canterbury Road  blackburn    1075000        4         2
# 6             1/24-26 Service Road  blackburn    1108000        3         2
# 7                     39 Pope Road  blackburn    1338000        3         2
# 8                28 Tyrrell Avenue  blackburn    1690000        3         2
# 9              314/21 Queen Street  blackburn     530000        2         2
# 10             314/21 Queen Street  blackburn     530000        2         2
# 11                  5/28 Lake Road  blackburn     633000        2         1
# 12              18 Pakenham Street  blackburn    1630000        3         2
# 13                48 Elmhurst Road  blackburn    1630000        3         2
# 14  410/394-398 Middleborough Road  blackburn     505000        2         2
# 15            3/41 Whitehorse Road  blackburn     850500        2         1
# 16                46 Alandale Road  blackburn    1391000        3         1
# 17          G02/17-21 Queen Street  blackburn     551000        2         2
# 18                     2 Pope Road  blackburn    1335000        3         1
# 19               23 Malcolm Street  blackburn    1408000        3         1
# 20              2/9 Station Street  blackburn     690000        2         1
# 21                  1A Vine Street  blackburn    1665000        3         2
# 22            3/109 Blackburn Road  blackburn     620000        2         1
# 23                  9 Linum Street  blackburn    2455000        4         2
# 24                5 Dickens Street  blackburn    1370000        4         2
# 25                24 Patricia Road  blackburn    1411000        4         2
# 26               22 Malcolm Street  blackburn    2000000        5         2
# 27             9 Beverley Crescent  blackburn    1235000        3         1
# 28                1/40 Kerr Street  blackburn     880000        3         2
# 29                5 Langtree Court  blackburn    1450000        4         2
# 30               41 Naughton Grove  blackburn    1430000        4         1
# 31            156 Springfield Road  blackburn     966000        4         2
# 32          217/17-21 Queen Street  blackburn     505000        2         2
# 33            1/5 Glen Ebor Avenue  blackburn     980000        3         2
# 34               40 Malcolm Street  blackburn    1439000        3         1
# 35            2/15 Whitehorse Road  blackburn    1145000        4         2
# 36                 2E Almer Avenue  blackburn    1122500        4         3
# 37      107/300 Middleborough Road  blackburn     375000        1         1
# 38          102/18 Whitehorse Road  blackburn     463000        2         2
# 39              33 Canterbury Road  blackburn    unknown        3         2
#
#    carspaces land area
# 0          2       638
# 1          2       651
# 2          2       274
# 3          2       591
# 4          2       692
# 5          2       611
# 6          2       305
# 7          1       600
# 8          1      1190
# 9          2   unknown
# 10         2   unknown
# 11         1   unknown
# 12         2       283
# 13         2      1072
# 14         2   unknown
# 15         2       217
# 16         1       627
# 17         1   unknown
# 18         1       623
# 19         1   unknown
# 20         2   unknown
# 21         2       764
# 22         1   unknown
# 23         2      1051
# 24         1       626
# 25         2       664
# 26         2       717
# 27         2       716
# 28         2       260
# 29         1       686
# 30         2       637
# 31         2       438
# 32         1   unknown
# 33         2       297
# 34         1       725
# 35         2   unknown
# 36         2   unknown
# 37         1   unknown
# 38         1   unknown
# 39         2       347
